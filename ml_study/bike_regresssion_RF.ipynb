# %%
import pandas as pd

# %%
train = pd.read_csv("/Users/hellothere/choi/07.study/dsschool/01.data/bike/train.csv", parse_dates =["datetime"])
test = pd.read_csv("/Users/hellothere/choi/07.study/dsschool/01.data/bike/test.csv",parse_dates =["datetime"])

# %%
print(train.shape)
print(test.shape)
train.head(5)
# Out:
# (10886, 12)
# (6493, 9)
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
print(test.shape)
test.head(5)
# Out:
# (6493, 9)
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
train["year"]   = train["datetime"].dt.year
train["month"]  = train["datetime"].dt.month
train["day"]    = train["datetime"].dt.day
train["hour"]   = train["datetime"].dt.hour
train["minute"] = train["datetime"].dt.minute
train["second"] = train["datetime"].dt.second
train["weekday"] = train["datetime"].dt.weekday
train["dayofweek"] = train["datetime"].dt.dayofweek

test["year"]    = test["datetime"].dt.year
test["month"]   = test["datetime"].dt.month
test["day"]     = test["datetime"].dt.day
test["hour"]    = test["datetime"].dt.hour
test["minute"]  = test["datetime"].dt.minute
test["second"]  = test["datetime"].dt.second
test["weekday"] = test["datetime"].dt.weekday
test["dayofweek"] = test["datetime"].dt.dayofweek

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count  year  month  day  hour  \
# 0        81        0.0       3          13     16  2011      1    1     0
# 1        80        0.0       8          32     40  2011      1    1     1
# 2        80        0.0       5          27     32  2011      1    1     2
# 3        75        0.0       3          10     13  2011      1    1     3
# 4        75        0.0       0           1      1  2011      1    1     4
#
#    minute  second  weekday  dayofweek
# ...

# %%
#train["season_A"] = train["season" == "1" ]


train["season_A"] = train["season" ] == 1 
train["season_B"] = train["season" ] == 2
train["season_C"] = train["season" ] == 3 
train["season_D"] = train["season" ] == 4 


test["season_A"] = test["season" ] == 1 
test["season_B"] = test["season" ] == 2
test["season_C"] = test["season" ] == 3 
test["season_D"] = test["season" ] == 4



train["weather_A"] = train["weather" ] == 1 
train["weather_B"] = train["weather" ] == 2
train["weather_C"] = train["weather" ] == 3 
train["weather_D"] = train["weather" ] == 4 


test["weather_A"] = test["weather" ] == 1 
test["weather_B"] = test["weather" ] == 2
test["weather_C"] = test["weather" ] == 3 
test["weather_D"] = test["weather" ] == 4

# %%
train["real"] = pd.to_numeric(train["atemp"]) - pd.to_numeric(train["temp"])
test["real"] = pd.to_numeric(test["atemp"]) - pd.to_numeric(test["temp"])

# %%
#mean_wind = train["windspeed"].mean()
#train["windspeed"].replace(0, mean_wind)

# %%
#print(train["temp"].mean())
#print(train["atemp"].mean())

train_1 = train[(train["season"] ==1)]
train_2 = train[(train["season"] ==2)]
train_3 = train[(train["season"] ==3)]
train_4 = train[(train["season"] ==4)]


print(train_1["windspeed"].mean())
print(train_2["windspeed"].mean())
print(train_3["windspeed"].mean())
print(train_4["windspeed"].mean())

#dfRefflat[(dfRefflat['cdsStart'] > 10000) & (dfRefflat['cdsEnd'] < 20000)]

## fill in windspeed 

train["next-wind"] = train["windspeed"].shift(+1)
train["prev-wind"] = train["windspeed"].shift(-1)
# Out:
# 14.636978145941786
# 13.405606622758746
# 11.508861873399052
# 11.678146561814088

# %%
train.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual    ...      season_B  season_C  season_D  \
# 0        81        0.0       3    ...         False     False     False
# 1        80        0.0       8    ...         False     False     False
# 2        80        0.0       5    ...         False     False     False
# 3        75        0.0       3    ...         False     False     False
# 4        75        0.0       0    ...         False     False     False
#
#    weather_A  weather_B  weather_C  weather_D   real  next-wind  prev-wind
# ...

# %%
train.corr()
# Out:
#               season   holiday  workingday   weather      temp     atemp  \
# season      1.000000  0.029368   -0.008126  0.008879  0.258689  0.264744
# holiday     0.029368  1.000000   -0.250491 -0.007074  0.000295 -0.005215
# workingday -0.008126 -0.250491    1.000000  0.033772  0.029966  0.024660
# weather     0.008879 -0.007074    0.033772  1.000000 -0.055035 -0.055376
# temp        0.258689  0.000295    0.029966 -0.055035  1.000000  0.984948
# atemp       0.264744 -0.005215    0.024660 -0.055376  0.984948  1.000000
# humidity    0.190610  0.001929   -0.010880  0.406244 -0.064949 -0.043536
# windspeed  -0.147121  0.008409    0.013373  0.007261 -0.017852 -0.057473
# casual      0.096758  0.043799   -0.319111 -0.135918  0.467097  0.462067
# registered  0.164011 -0.020956    0.119460 -0.109340  0.318571  0.314635
# count       0.163439 -0.005393    0.011594 -0.128655  0.394454  0.389784
# year       -0.004797  0.012021   -0.002482 -0.012548  0.061226  0.058540
# ...

# %%
import seaborn as sns
# %matplotlib inline
sns.heatmap(train.corr())

#r = sns.heatmap(flight_matrix, cmap='BuPu')
#r.set_title("Heatmap of Flight Density from 1949 to 1961")

# %%
train.plot.box()

# %% [markdown]
# # Train

# %%
#feature_names = ["season_A","season_B","season_C","season_D","workingday","humidity","month","hour","temp","year","weekday","windspeed","weather"] 

#0.380
#feature_names = ["season","season_A","season_B","season_C","season_D","workingday","humidity","month","hour","temp","year","weekday","windspeed","weather"]

#0.37696
#feature_names = ["season","season_A","season_B","season_C","season_D","workingday","humidity","month","hour","temp","year","weekday","weather"]

#0.37531
#feature_names = ["season","season_A","season_B","season_C","season_D","workingday","humidity","month","hour","temp","year","weekday","weather","minute"]

#0.37456
#feature_names = [ "season","workingday","humidity","month","hour","temp","year","weekday","weather","minute"]

#0.37456
#feature_names = [ "season","workingday","humidity","month","hour","temp","year","weekday","weather","minute"]

#0.37456
#feature_names = [ "season","workingday","humidity","month","hour","temp","year","weekday","weather","minute"]

#0.37610 
#feature_names = [ "season","workingday","humidity","temp","weather","month","hour","year","weekday"]

#0.38055 
#feature_names = [ "season","workingday","humidity","weather","month","hour","year","weekday","temp","windspeed",]

#0.38055 
feature_names = [ "hour","day","year","workingday","weather","atemp","season","humidity"]

# %%
X_train = train[feature_names]
print(X_train.shape)
X_train.head()
# Out:
# (10886, 8)
#    hour  day  year  workingday  weather   atemp  season  humidity
# 0     0    1  2011           0        1  14.395       1        81
# 1     1    1  2011           0        1  13.635       1        80
# 2     2    1  2011           0        1  13.635       1        80
# 3     3    1  2011           0        1  14.395       1        75
# 4     4    1  2011           0        1  14.395       1        75

# %%
X_test = test[feature_names]
print(X_test.shape)
X_test.head()
# Out:
# (6493, 8)
#    hour  day  year  workingday  weather   atemp  season  humidity
# 0     0   20  2011           1        1  11.365       1        56
# 1     1   20  2011           1        1  13.635       1        56
# 2     2   20  2011           1        1  13.635       1        56
# 3     3   20  2011           1        1  12.880       1        56
# 4     4   20  2011           1        1  12.880       1        56

# %%
label_name= "count"
y_train = train[label_name]
print(y_train.shape)
y_train.head()
# Out:
# (10886,)
# 0    16
# 1    40
# 2    32
# 3    13
# 4     1
# Name: count, dtype: int64

# %%
#from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor 
model = RandomForestRegressor(random_state=100)
model
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=100, verbose=0, warm_start=False)

# %%
import numpy as np
from sklearn.metrics import make_scorer

def rmsle(predict, actual):
    predict = np.array(predict)
    actual = np.array(actual)
    
    log_predict = np.log(predict + 1)
    log_actual = np.log(actual + 1)
    
    difference = log_predict - log_actual
    difference = np.square(difference)
    
    mean_difference = difference.mean()
    
    score = np.sqrt(mean_difference)
    
    return score

rmsle_scorer = make_scorer(rmsle)
rmsle_scorer
# Out:
# make_scorer(rmsle)

# %%
from sklearn.model_selection import cross_val_score

score = cross_val_score(model, X_train, y_train,
                        cv=20, scoring=rmsle_scorer).mean()

print("Score = {0:.5f}".format(score))
# Out:
# Score = 0.41374

# %% [markdown]
# # Score

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=50, verbose=0, warm_start=False)

# %%
predictions = model.predict(X_test)

# %%
submit = pd.read_csv("/Users/hellothere/choi/07.study/dsschool/01.data/bike/sampleSubmission.csv")
print(submit.shape)
submit.head()
# Out:
# (6493, 2)
#               datetime  count
# 0  2011-01-20 00:00:00      0
# 1  2011-01-20 01:00:00      0
# 2  2011-01-20 02:00:00      0
# 3  2011-01-20 03:00:00      0
# 4  2011-01-20 04:00:00      0

# %%
submit["count"] = predictions
submit.to_csv("/Users/hellothere/choi/07.study/dsschool/01.data/bike/first.csv", index=False)
