# %%
import pandas as pd

# %%
train = pd.read_csv("/Users/hellothere/choi/07.study/dsschool/01.data/titanic/train.csv", index_col="PassengerId")

# %%
print(train.shape)
# Out:
# (891, 11)

# %% [markdown]
# ## EDA

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %%
sns.countplot(data= train, x = "Embarked", hue = "Survived") ## hue를 기반으로 분리하여 시각화

# %%
sns.countplot(data = train , x = "Pclass", hue = "Survived")

# %% [markdown]
# ## barplot

# %%
## 컬럼이 이산형일때 
sns.barplot(data = train, x= "Pclass" , y = "Fare", hue = "Survived") ## 데이터가 범주형 / 단위형 어떤걸 쓰냐도 중요

# %% [markdown]
# ## Point Plot

# %%
sns.pointplot(data = train, x= "Pclass" , y = "Fare", hue = "Survived")

# %% [markdown]
# ## DistPlot

# %%
sns.distplot(train["Fare"])

# %%
sns.distplot(train["Fare"], hist = 0)

# %%
low_fare = train[train["Fare"] < 500]
sns.distplot(low_fare["Fare"] , hist =0 )

# %%
low_fare = train[train["Fare"] < 100]

perish   = low_fare[low_fare["Survived"] == 0 ]
survived = low_fare[low_fare["Survived"] == 1 ]

sns.distplot(perish["Fare"]  , hist = False , label = "perish")
sns.distplot(survived["Fare"], hist = False , label = "survived")

# %% [markdown]
# ## lmplot

# %%
sns.lmplot(data = train , x ="Age" , y = "Fare", hue = "Survived", fit_reg = False )

# %%
low_fare = train[train["Fare"] < 500 ]

sns.lmplot(data = low_fare , x = "Age", y ="Fare" , hue = "Survived", fit_reg = False )

# %% [markdown]
# ## subplot

# %%
sns.countplot(data = train , x = "Embarked")

# %%
import matplotlib.pyplot as plt

figure , ((ax1, ax2 , ax3 ) (ax4, ax5 , ax6 ) ) = plt.subplot(nrows =2 , ncols = 3 )


#sns.countplot(data = train , x = "Embarked")
# Out:
#   File "<ipython-input-68-31924eac171d>", line 3
#     figure , ((ax1, ax2 , ax3 ) (ax4, ax5 , ax6 ) ) = plt.subplot(nrows =2 , ncols = 3 )
#                                                                                         ^
# SyntaxError: can't assign to function call

# %%
import matplotlib.pyplot as plt

figure , ((ax1, ax2 , ax3 ), (ax4, ax5 , ax6 )) = plt.subplots(nrows =2, ncols=3)
figure.set_size_inches(18 , 8)




sns.countplot(data = train , x = "Embarked" ,ax = ax1)
sns.countplot(data = train , x = "Age"      ,ax = ax2)
sns.countplot(data = train , x = "Sex"      ,ax = ax3)
sns.countplot(data = train , x = "Pclass" ,ax = ax4)
sns.countplot(data = train , x = "Parch" ,ax = ax5)
sns.countplot(data = train , x = "SibSp" ,ax = ax6)

# %%
not_three = train[train["Pclass"] != 3]

# %%
train.shape
# Out:
# (891, 11)

# %%
not_three.shape
# Out:
# (400, 11)
