# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Dataset

# %%
# 경로(ex: data/bike/train.csv)는 사용자 설정마다 다를 수 있음.
train = pd.read_csv("/Users/hellothere/choi/07.study/dsschool/01.data/bike/train.csv", parse_dates =["datetime"])
test = pd.read_csv("/Users/hellothere/choi/07.study/dsschool/01.data/bike/test.csv",parse_dates =["datetime"])
print(train.shape)
train.head()
# Out:
# (10886, 12)
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
print(test.shape)
test.head()
# Out:
# (6493, 9)
#              datetime  season  holiday  workingday  weather   temp   atemp  \
# 0 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed
# 0        56    26.0027
# 1        56     0.0000
# 2        56     0.0000
# 3        56    11.0014
# 4        56    11.0014

# %%
#train[["casual","registered","count"]]
train["season_A"] = train["season" ] == 1 
train["season_B"] = train["season" ] == 2
train["season_C"] = train["season" ] == 3 
train["season_D"] = train["season" ] == 4 


test["season_A"] = test["season" ] == 1 
test["season_B"] = test["season" ] == 2
test["season_C"] = test["season" ] == 3 
test["season_D"] = test["season" ] == 4



train["weather_A"] = train["weather" ] == 1 
train["weather_B"] = train["weather" ] == 2
train["weather_C"] = train["weather" ] == 3 
train["weather_D"] = train["weather" ] == 4 


test["weather_A"] = test["weather" ] == 1 
test["weather_B"] = test["weather" ] == 2
test["weather_C"] = test["weather" ] == 3 
test["weather_D"] = test["weather" ] == 4

# %%
np.log1p[train["casual"]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-716-8a0caf6fdfe9> in <module>()
# ----> 1 np.log1p[train["casual"]]
#
# TypeError: 'numpy.ufunc' object is not subscriptable

# %%
#low = train[train["windspeed"] > 10]
#low2 = test[test["windspeed"] > 10]

#sns.distplot(train["windspeed"] , hist =0 )
#sns.distplot(test["windspeed"] , hist =0)

 

figure, ax3 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(30, 4)


sns.barplot(data = train, x= "windspeed" , y = "count")

# %%
#print(train.shape)

#train = train[train["windspeed"] != 51.9987 ]

#print(train.shape )
#train

# %%
print(train.shape )
# Out:
# (10886, 20)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# ### Parse datetime

# %%
train["datetime-year"] = train["datetime"].dt.year
train["datetime-month"] = train["datetime"].dt.month
train["datetime-day"] = train["datetime"].dt.day
train["datetime-hour"] = train["datetime"].dt.hour
train["datetime-minute"] = train["datetime"].dt.minute
train["datetime-second"] = train["datetime"].dt.second
train["datetime-dayofweek"] = train["datetime"].dt.dayofweek

print(train.shape)
train[["datetime", "datetime-year", "datetime-month", "datetime-day", "datetime-hour", "datetime-minute", "datetime-second", "datetime-dayofweek"]].head()
# Out:
# (10886, 27)
#              datetime  datetime-year  datetime-month  datetime-day  \
# 0 2011-01-01 00:00:00           2011               1             1
# 1 2011-01-01 01:00:00           2011               1             1
# 2 2011-01-01 02:00:00           2011               1             1
# 3 2011-01-01 03:00:00           2011               1             1
# 4 2011-01-01 04:00:00           2011               1             1
#
#    datetime-hour  datetime-minute  datetime-second  datetime-dayofweek
# 0              0                0                0                   5
# 1              1                0                0                   5
# 2              2                0                0                   5
# 3              3                0                0                   5
# 4              4                0                0                   5

# %%
test["datetime-year"] = test["datetime"].dt.year
test["datetime-month"] = test["datetime"].dt.month
test["datetime-day"] = test["datetime"].dt.day
test["datetime-hour"] = test["datetime"].dt.hour
test["datetime-minute"] = test["datetime"].dt.minute
test["datetime-second"] = test["datetime"].dt.second
test["datetime-dayofweek"] = test["datetime"].dt.dayofweek

print(test.shape)
test[["datetime", "datetime-year", "datetime-month", "datetime-day", "datetime-hour", "datetime-minute", "datetime-second", "datetime-dayofweek"]].head()
# Out:
# (6493, 24)
#              datetime  datetime-year  datetime-month  datetime-day  \
# 0 2011-01-20 00:00:00           2011               1            20
# 1 2011-01-20 01:00:00           2011               1            20
# 2 2011-01-20 02:00:00           2011               1            20
# 3 2011-01-20 03:00:00           2011               1            20
# 4 2011-01-20 04:00:00           2011               1            20
#
#    datetime-hour  datetime-minute  datetime-second  datetime-dayofweek
# 0              0                0                0                   3
# 1              1                0                0                   3
# 2              2                0                0                   3
# 3              3                0                0                   3
# 4              4                0                0                   3

# %% [markdown]
# ## Explore

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### datetime

# %%
figure, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
figure.set_size_inches(18, 8)

sns.barplot(data=train, x="datetime-year", y="count", ax=ax1)
sns.barplot(data=train, x="datetime-month", y="count", ax=ax2)
sns.barplot(data=train, x="datetime-day", y="count", ax=ax3)
sns.barplot(data=train, x="datetime-hour", y="count", ax=ax4)
sns.barplot(data=train, x="datetime-minute", y="count", ax=ax5)
sns.barplot(data=train, x="datetime-second", y="count", ax=ax6)

# %%
figure, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(nrows=2, ncols=3)
figure.set_size_inches(18, 8)

sns.barplot(data=train, x="windspeed", y="count", ax=ax1)
sns.barplot(data=train, x="temp", y="count", ax=ax2)
sns.barplot(data=train, x="weather", y="count", ax=ax3)
sns.barplot(data=train, x="humidity", y="count", ax=ax4)
sns.barplot(data=train, x="holiday", y="count", ax=ax5)
sns.barplot(data=train, x="workingday", y="count", ax=ax6)

# %%
train["datetime-year_month"] = train["datetime"].dt.year.astype('str') + '-' + train["datetime"].dt.month.astype('str')

print(train.shape)
train[["datetime", "datetime-year_month"]].head()
# Out:
# (10886, 28)
#              datetime datetime-year_month
# 0 2011-01-01 00:00:00              2011-1
# 1 2011-01-01 01:00:00              2011-1
# 2 2011-01-01 02:00:00              2011-1
# 3 2011-01-01 03:00:00              2011-1
# 4 2011-01-01 04:00:00              2011-1

# %%
figure, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)
figure.set_size_inches(18, 4)

sns.barplot(data=train, x="datetime-year", y="count", ax=ax1)
sns.barplot(data=train, x="datetime-month", y="count", ax=ax2)

figure, ax3 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18, 4)

sns.barplot(data=train, x="datetime-year_month", y="count", ax=ax3)

# %%
figure, ax1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18, 4)

sns.pointplot(data=train, x="datetime-hour", y="count", hue="workingday", ax=ax1)

figure, ax2 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18, 4)

sns.pointplot(data=train, x="datetime-hour", y="count", hue="datetime-dayofweek", ax=ax2)

# %%
figure, (ax1, ax2, ax3) = plt.subplots(nrows=3, ncols=1)
figure.set_size_inches(18, 12)

sns.pointplot(data=train, x="datetime-hour", y="count", hue="workingday", ax=ax1)
sns.pointplot(data=train, x="datetime-hour", y="casual", hue="workingday", ax=ax2)
sns.pointplot(data=train, x="datetime-hour", y="registered", hue="workingday", ax=ax3)

# %%
# 0.37926
#feature_names = ["season", "holiday", "workingday", "weather",  "temp", "atemp", "humidity", "windspeed","datetime-year", "datetime-hour", "datetime-dayofweek"]
# 0.37879
#feature_names = ["season", "holiday", "workingday", "weather", "atemp", "humidity", "windspeed","datetime-year", "datetime-hour", "datetime-dayofweek"]
#0.37470
#feature_names = ["season", "workingday", "weather", "atemp", "humidity","datetime-year", "datetime-hour", "datetime-dayofweek"]
#0.37355
#feature_names = ["season_A","season_B","season_C","season_D","humidity", "workingday","weather","atemp","datetime-year", "datetime-hour", "datetime-dayofweek"]

#0.37383
feature_names = ["weather_A","weather_B","weather_C","weather_D","season_A","season_B","season_C","season_D","humidity", "workingday", "temp", "atemp","datetime-year", "datetime-hour", "datetime-dayofweek"]

#0.37383
#feature_names = ["windspeed","weather_A","weather_B","weather_C","weather_D","season_A","season_B","season_C","season_D","humidity", "workingday","atemp","datetime-year", "datetime-hour", "datetime-dayofweek"]
 
feature_names
# Out:
# ['weather_A',
#  'weather_B',
#  'weather_C',
#  'weather_D',
#  'season_A',
#  'season_B',
#  'season_C',
#  'season_D',
#  'humidity',
#  'workingday',
#  'atemp',
#  'datetime-year',
#  'datetime-hour',
#  'datetime-dayofweek']

# %%
X_train = train[feature_names]

print(X_train.shape)
X_train.head()
# Out:
# (10886, 14)
#    weather_A  weather_B  weather_C  weather_D  season_A  season_B  season_C  \
# 0       True      False      False      False      True     False     False
# 1       True      False      False      False      True     False     False
# 2       True      False      False      False      True     False     False
# 3       True      False      False      False      True     False     False
# 4       True      False      False      False      True     False     False
#
#    season_D  humidity  workingday   atemp  datetime-year  datetime-hour  \
# 0     False        81           0  14.395           2011              0
# 1     False        80           0  13.635           2011              1
# 2     False        80           0  13.635           2011              2
# 3     False        75           0  14.395           2011              3
# 4     False        75           0  14.395           2011              4
#
#    datetime-dayofweek
# 0                   5
# ...

# %%
X_test = test[feature_names]

print(X_test.shape)
X_test.head()
# Out:
# (6493, 14)
#    weather_A  weather_B  weather_C  weather_D  season_A  season_B  season_C  \
# 0       True      False      False      False      True     False     False
# 1       True      False      False      False      True     False     False
# 2       True      False      False      False      True     False     False
# 3       True      False      False      False      True     False     False
# 4       True      False      False      False      True     False     False
#
#    season_D  humidity  workingday   atemp  datetime-year  datetime-hour  \
# 0     False        56           1  11.365           2011              0
# 1     False        56           1  13.635           2011              1
# 2     False        56           1  13.635           2011              2
# 3     False        56           1  12.880           2011              3
# 4     False        56           1  12.880           2011              4
#
#    datetime-dayofweek
# 0                   3
# ...

# %%
label_name = "count"

y_train = train[label_name]

print(y_train.shape)
y_train.head()
# Out:
# (10886,)
# 0    16
# 1    40
# 2    32
# 3    13
# 4     1
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor(random_state=37,
                              min_samples_split=6,
                              min_samples_leaf=2,
                              n_estimators=300 , 
                              n_jobs=-1 )
model
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=50,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=2, min_samples_split=6,
#            min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=-1,
#            oob_score=False, random_state=37, verbose=0, warm_start=False)

# %% [markdown]
# ## Score

# %% [markdown]
# Evaluation Metric = **Root Mean Squared Logarithmic Error** (RMSLE)
#
# $$ \sqrt{\frac{1}{n} \sum_{i=1}^n (\log(p_i + 1) - \log(a_i+1))^2 } $$

# %%
import numpy as np
from sklearn.metrics import make_scorer

def rmsle(predict, actual):
    predict = np.array(predict)
    actual = np.array(actual)
    
    log_predict = np.log(predict + 1)
    log_actual = np.log(actual + 1)
    
    difference = log_predict - log_actual
    difference = np.square(difference)
    
    mean_difference = difference.mean()
    
    score = np.sqrt(mean_difference)
    
    return score

rmsle_scorer = make_scorer(rmsle)
rmsle_scorer
# Out:
# make_scorer(rmsle)

# %%
from sklearn.model_selection import cross_val_score

score = cross_val_score(model, X_train, y_train,
                        cv=20, scoring=rmsle_scorer).mean()

print("Score = {0:.5f}".format(score))
# Out:
# Score = 0.36624

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=50,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=2, min_samples_split=6,
#            min_weight_fraction_leaf=0.0, n_estimators=300, n_jobs=-1,
#            oob_score=False, random_state=37, verbose=0, warm_start=False)

# %%
predictions = model.predict(X_test)

print(predictions.shape)
predictions[0:10]
# Out:
# (6493,)
# array([  10.9512708 ,    5.02507239,    3.93563781,    3.81287821,
#           3.00276746,    5.92608057,   37.35780315,   97.13892569,
#         233.11602528,  132.59607217])

# %%
submit = pd.read_csv("/Users/hellothere/choi/07.study/dsschool/01.data/bike/sampleSubmission.csv")

print(submit.shape)
submit.head()
# Out:
# (6493, 2)
#               datetime  count
# 0  2011-01-20 00:00:00      0
# 1  2011-01-20 01:00:00      0
# 2  2011-01-20 02:00:00      0
# 3  2011-01-20 03:00:00      0
# 4  2011-01-20 04:00:00      0

# %%
submit["count"] = predictions

print(submit.shape)
submit.head()
# Out:
# (6493, 2)
#               datetime      count
# 0  2011-01-20 00:00:00  10.951271
# 1  2011-01-20 01:00:00   5.025072
# 2  2011-01-20 02:00:00   3.935638
# 3  2011-01-20 03:00:00   3.812878
# 4  2011-01-20 04:00:00   3.002767

# %%
submit.to_csv("/Users/hellothere/choi/07.study/dsschool/01.data/bike/Submission_choi.csv", index=False)
